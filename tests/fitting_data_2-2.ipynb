# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %%
import numpy as np
import time

# %%
from rxrmask.core import (
    Atom,
    Structure,
    FormFactorLocalDB,
    FormFactorFile,
    ParametersContainer,
    create_compound,
    load_reflectivity_scans,
    ReflectivityScan,
    EnergyScan, load_energy_scans,
)
from rxrmask.utils import (
    plot_reflectivity,
    plot_energy_scan,
    plot_density_profile,
    get_density_profile_from_element_data,
plot_density_profile_atoms_layers
)
from rxrmask.backends import (
    PRReflectivityBackend,
    PRParallelReflectivityBackend,
)
from rxrmask.optimization import fit_differential_evolution, FitContext, FitTransform, TVRegularizer

# %%
o_ff = FormFactorFile(path="/Users/niaggar25/Downloads/Experimental RXR data/O.ff")
sr_ff = FormFactorFile(path="/Users/niaggar25/Downloads/Experimental RXR data/Sr.ff")
ti_ff = FormFactorFile(path="/Users/niaggar25/Downloads/Experimental RXR data/Ti.ff")
o_atom = Atom(
    Z=8,
    name="O",
    ff=o_ff,
)
sr_atom = Atom(
    Z=38,
    name="Sr",
    ff=sr_ff,
)
ti_atom = Atom(
    Z=22,
    name="Ti",
    ff=ti_ff,
)

# %%
parameters_container = ParametersContainer()
crystal = create_compound(
    parameters_container=parameters_container,
    name="SrTiO3-crystal",
    formula="Sr:1,Ti:1,O:3",
    thickness=50.0,
    density=5.12,
    atoms=[sr_atom, ti_atom, o_atom],
    roughness=2.0,
    prev_roughness=0.0,
    linked_prev_roughness=False,
)

n_films = 4
init_thickness = 24.0
dthickness = init_thickness / n_films
density = 5.12
films = []
for i in range(n_films):
    film = create_compound(
        parameters_container=parameters_container,
        name=f"SrTiO3-film-{i}",
        formula="Sr:1,Ti:1,O:3",
        thickness=dthickness,
        density=density,
        atoms=[sr_atom, ti_atom, o_atom],
        roughness=1.0,
        prev_roughness=0.0,
        linked_prev_roughness=True,
    )
    films.append(film)

struc = Structure(name="SrTiO3-struc", n_compounds=n_films+1, params_container=parameters_container)
struc.add_compound(0, crystal)
for i, film in enumerate(films):
    struc.add_compound(i + 1, film)
struc.validate_compounds()

for detail in crystal.compound_details:
    detail.roughness.independent = True
    detail.roughness.fit = True
    detail.roughness.upper = 5.0
    detail.roughness.lower = 1.0

crystal.compound_details[0].roughness.set(3.8637948057808016)
crystal.compound_details[1].roughness.set(2.496378890161917)
crystal.compound_details[2].roughness.set(4.834399517466396)

def params_for_films(film):
    for detail in film.compound_details:
        detail.roughness.independent = True
        detail.roughness.fit = True
        detail.roughness.upper = 5.0
        detail.roughness.lower = 0.0

        detail.molar_density.independent = True
        detail.molar_density.fit = True
        detail.molar_density.set(0.04)
        detail.molar_density.upper = 0.09
        detail.molar_density.lower = 0

        detail.thickness.independent = False
        detail.thickness.fit = False
        # detail.thickness.upper = 7.0
        # detail.thickness.lower = 0.1

        detail.prev_roughness.independent = False
        detail.prev_roughness.fit = False
        # detail.prev_roughness.upper = 5.0
        # detail.prev_roughness.lower = 0.0


for film in films:
    params_for_films(film)

struc.create_layers(step=0.1)

def print_parameters(params_container):
    params_vals = params_container.get_fit_vector()
    print(f"Current params: {params_vals}")
    for param in params_container.parameters:
        if param.fit:
            print(f"{param.name}: {param.value}")


# print(f"Number of layers: {struc.n_layers}")
print_parameters(parameters_container)
plot_density_profile_atoms_layers(struc.atoms_layers)
# Out:
# Number of layers: 890
# Current params: [3.8637948057808016, 2.496378890161917, 4.834399517466396, 0.04, 1.0, 0.04, 1.0, 0.04, 1.0, 0.04, 1.0, 0.04, 1.0, 0.04, 1.0, 0.04, 1.0, 0.04, 1.0, 0.04, 1.0, 0.04, 1.0, 0.04, 1.0, 0.04, 1.0]
# SrTiO3-crystal-Sr-roughness: 3.8637948057808016
# SrTiO3-crystal-Ti-roughness: 2.496378890161917
# SrTiO3-crystal-O-roughness: 4.834399517466396
# SrTiO3-film-0-Sr-molar_density: 0.04
# SrTiO3-film-0-Sr-roughness: 1.0
# SrTiO3-film-0-Ti-molar_density: 0.04
# SrTiO3-film-0-Ti-roughness: 1.0
# SrTiO3-film-0-O-molar_density: 0.04
# SrTiO3-film-0-O-roughness: 1.0
# SrTiO3-film-1-Sr-molar_density: 0.04
# SrTiO3-film-1-Sr-roughness: 1.0
# SrTiO3-film-1-Ti-molar_density: 0.04
# SrTiO3-film-1-Ti-roughness: 1.0
# SrTiO3-film-1-O-molar_density: 0.04
# SrTiO3-film-1-O-roughness: 1.0
# SrTiO3-film-2-Sr-molar_density: 0.04
# SrTiO3-film-2-Sr-roughness: 1.0
# SrTiO3-film-2-Ti-molar_density: 0.04
# SrTiO3-film-2-Ti-roughness: 1.0
# SrTiO3-film-2-O-molar_density: 0.04
# SrTiO3-film-2-O-roughness: 1.0
# SrTiO3-film-3-Sr-molar_density: 0.04
# SrTiO3-film-3-Sr-roughness: 1.0
# SrTiO3-film-3-Ti-molar_density: 0.04
# SrTiO3-film-3-Ti-roughness: 1.0
# SrTiO3-film-3-O-molar_density: 0.04
# SrTiO3-film-3-O-roughness: 1.0

# %%
experimental_rscans = load_reflectivity_scans(
    path='/Users/niaggar25/Downloads/Experimental RXR data/B074_AScans.dat',
    initial_name='B074_AScans',
)
experimental_escans = load_energy_scans(
    path='/Users/niaggar25/Downloads/Experimental RXR data/B074_EScans.dat',
    initial_name='B074_EScans',
)

# %%
for film in films:
    for detail in film.compound_details:
        detail.roughness.fit = True
        detail.molar_density.fit = True
        detail.thickness.fit = False

crystal.thickness.set(10)
struc.update_layers()
plot_density_profile_atoms_layers(struc.atoms_layers)

# %%
backend = PRReflectivityBackend(als=True)
scale_param = parameters_container.new_parameter("scale", value=1.0, fit=False)
offset_param = parameters_container.new_parameter("offset", value=0.0, fit=False)

context = FitContext(
    backend=backend,
    structure=struc,
    transform=FitTransform(r_scale="ln", sim_scale=scale_param, sim_offset=offset_param),
    tv=TVRegularizer(),
    objective="chi2",
)
parameters = [
    param for param in parameters_container.parameters if param.fit
]

print(len(parameters))

res = fit_differential_evolution(
    params=parameters,
    ctx=context,
    ref_scans=experimental_rscans[5:12],
    en_scans=[],
    popsize=6,
)


print(res)
print("Final parameters:")
print_parameters(parameters_container)
# Out:
# 27
# Data ready
# differential_evolution step 1: f(x)= 522.7430922483933
# differential_evolution step 2: f(x)= 522.7430922483933
# differential_evolution step 3: f(x)= 463.8255682896012
# differential_evolution step 4: f(x)= 456.1194964375373
# differential_evolution step 5: f(x)= 456.1194964375373
# differential_evolution step 6: f(x)= 456.1194964375373
# differential_evolution step 7: f(x)= 456.1194964375373
# differential_evolution step 8: f(x)= 420.79505104571706
# differential_evolution step 9: f(x)= 420.79505104571706
# differential_evolution step 10: f(x)= 420.79505104571706
# differential_evolution step 11: f(x)= 420.79505104571706
# differential_evolution step 12: f(x)= 420.79505104571706
# differential_evolution step 13: f(x)= 420.79505104571706
# differential_evolution step 14: f(x)= 420.79505104571706
# differential_evolution step 15: f(x)= 420.6425362109181
# differential_evolution step 16: f(x)= 420.6425362109181
# differential_evolution step 17: f(x)= 419.0876307978871
# differential_evolution step 18: f(x)= 411.93880800000517
# differential_evolution step 19: f(x)= 411.93880800000517
# differential_evolution step 20: f(x)= 407.9734573309613
# differential_evolution step 21: f(x)= 407.9734573309613
# differential_evolution step 22: f(x)= 407.9734573309613
# differential_evolution step 23: f(x)= 407.9734573309613
# differential_evolution step 24: f(x)= 407.9734573309613
# differential_evolution step 25: f(x)= 407.9734573309613
# differential_evolution step 26: f(x)= 407.9734573309613
# differential_evolution step 27: f(x)= 407.9734573309613
# differential_evolution step 28: f(x)= 407.9734573309613
# differential_evolution step 29: f(x)= 407.9734573309613
# differential_evolution step 30: f(x)= 407.9734573309613
# differential_evolution step 31: f(x)= 407.9734573309613
# differential_evolution step 32: f(x)= 407.9734573309613
# differential_evolution step 33: f(x)= 407.9734573309613
# differential_evolution step 34: f(x)= 407.9734573309613
# differential_evolution step 35: f(x)= 407.9734573309613
# differential_evolution step 36: f(x)= 407.9734573309613
# differential_evolution step 37: f(x)= 407.26612121715243
# differential_evolution step 38: f(x)= 404.8172539493914
# differential_evolution step 39: f(x)= 404.8172539493914
# differential_evolution step 40: f(x)= 404.8172539493914
# differential_evolution step 41: f(x)= 401.6346660849386
# differential_evolution step 42: f(x)= 401.6346660849386
# differential_evolution step 43: f(x)= 401.6346660849386
# differential_evolution step 44: f(x)= 401.6346660849386
# differential_evolution step 45: f(x)= 401.6346660849386
# differential_evolution step 46: f(x)= 401.6346660849386
# differential_evolution step 47: f(x)= 401.6346660849386
# differential_evolution step 48: f(x)= 399.6900798407905
# differential_evolution step 49: f(x)= 399.6900798407905
# differential_evolution step 50: f(x)= 399.6900798407905
# (array([2.94597181, 2.58901694, 1.97852702, 0.04133688, 4.24910594,
#        0.02413277, 2.31786093, 0.01692333, 0.78207757, 0.02008147,
#        2.94914134, 0.04435273, 0.4430255 , 0.01432292, 0.83933697,
#        0.03327374, 0.9598767 , 0.01283354, 4.0776846 , 0.02641654,
#        4.05939787, 0.02657796, 0.48603275, 0.02522159, 4.79345115,
#        0.02725083, 4.59527635]), 399.6900798407905)
# Final parameters:
# Current params: [2.196917314595915, 2.5910755330932753, 3.5399119280579985, 0.029776221516464377, 2.5374288088958874, 0.02191243758041929, 2.401421107336326, 0.03762138451495314, 0.8204214967645727, 0.025508975370324427, 1.4699996109091484, 0.0384265690512097, 0.2834396367499674, 0.019289219219730275, 3.8810906406361627, 0.026291026919270048, 2.732435723027004, 0.02637021094283215, 3.9279130189804645, 0.04845953052127307, 2.8377697564276656, 0.028362691697693034, 3.151544464201196, 0.022340611439236702, 3.494144039437812, 0.001114768574900754, 1.7955672217116125]
# SrTiO3-crystal-Sr-roughness: 2.196917314595915
# SrTiO3-crystal-Ti-roughness: 2.5910755330932753
# SrTiO3-crystal-O-roughness: 3.5399119280579985
# SrTiO3-film-0-Sr-molar_density: 0.029776221516464377
# SrTiO3-film-0-Sr-roughness: 2.5374288088958874
# SrTiO3-film-0-Ti-molar_density: 0.02191243758041929
# SrTiO3-film-0-Ti-roughness: 2.401421107336326
# SrTiO3-film-0-O-molar_density: 0.03762138451495314
# SrTiO3-film-0-O-roughness: 0.8204214967645727
# SrTiO3-film-1-Sr-molar_density: 0.025508975370324427
# SrTiO3-film-1-Sr-roughness: 1.4699996109091484
# SrTiO3-film-1-Ti-molar_density: 0.0384265690512097
# SrTiO3-film-1-Ti-roughness: 0.2834396367499674
# SrTiO3-film-1-O-molar_density: 0.019289219219730275
# SrTiO3-film-1-O-roughness: 3.8810906406361627
# SrTiO3-film-2-Sr-molar_density: 0.026291026919270048
# SrTiO3-film-2-Sr-roughness: 2.732435723027004
# SrTiO3-film-2-Ti-molar_density: 0.02637021094283215
# SrTiO3-film-2-Ti-roughness: 3.9279130189804645
# SrTiO3-film-2-O-molar_density: 0.04845953052127307
# SrTiO3-film-2-O-roughness: 2.8377697564276656
# SrTiO3-film-3-Sr-molar_density: 0.028362691697693034
# SrTiO3-film-3-Sr-roughness: 3.151544464201196
# SrTiO3-film-3-Ti-molar_density: 0.022340611439236702
# SrTiO3-film-3-Ti-roughness: 3.494144039437812
# SrTiO3-film-3-O-molar_density: 0.001114768574900754
# SrTiO3-film-3-O-roughness: 1.7955672217116125

# %%
crystal.thickness.set(10)
struc.update_layers()
plot_density_profile_atoms_layers(struc.atoms_layers)
for rscan in experimental_rscans[5:12]:
    rsim = backend.compute_reflectivity(structure=struc, qz=rscan.qz, energy=rscan.energy_eV)
    r = rsim.R_s if rscan.pol == "s" else rsim.R_p

    plot_reflectivity(rscan.qz, rscan.R, np.log(r), rscan.energy_eV, f"Energy scan {rscan.name}")

# %%
print("Initial parameters:")
print_parameters(parameters_container)

parameters = [
    param for param in parameters_container.parameters if param.fit
]

print(len(parameters))

res = fit_differential_evolution(
    params=parameters,
    ctx=context,
    ref_scans=experimental_rscans[0:5],
    en_scans=[],
)

print(res)
print("Final parameters:")
print_parameters(parameters_container)
plot_density_profile_atoms_layers(struc.atoms_layers)
# Out:
# Initial parameters:
# Current params: [2.196917314595915, 2.5910755330932753, 3.5399119280579985, 0.029776221516464377, 2.5374288088958874, 0.02191243758041929, 2.401421107336326, 0.03762138451495314, 0.8204214967645727, 0.025508975370324427, 1.4699996109091484, 0.0384265690512097, 0.2834396367499674, 0.019289219219730275, 3.8810906406361627, 0.026291026919270048, 2.732435723027004, 0.02637021094283215, 3.9279130189804645, 0.04845953052127307, 2.8377697564276656, 0.028362691697693034, 3.151544464201196, 0.022340611439236702, 3.494144039437812, 0.001114768574900754, 1.7955672217116125]
# SrTiO3-crystal-Sr-roughness: 2.196917314595915
# SrTiO3-crystal-Ti-roughness: 2.5910755330932753
# SrTiO3-crystal-O-roughness: 3.5399119280579985
# SrTiO3-film-0-Sr-molar_density: 0.029776221516464377
# SrTiO3-film-0-Sr-roughness: 2.5374288088958874
# SrTiO3-film-0-Ti-molar_density: 0.02191243758041929
# SrTiO3-film-0-Ti-roughness: 2.401421107336326
# SrTiO3-film-0-O-molar_density: 0.03762138451495314
# SrTiO3-film-0-O-roughness: 0.8204214967645727
# SrTiO3-film-1-Sr-molar_density: 0.025508975370324427
# SrTiO3-film-1-Sr-roughness: 1.4699996109091484
# SrTiO3-film-1-Ti-molar_density: 0.0384265690512097
# SrTiO3-film-1-Ti-roughness: 0.2834396367499674
# SrTiO3-film-1-O-molar_density: 0.019289219219730275
# SrTiO3-film-1-O-roughness: 3.8810906406361627
# SrTiO3-film-2-Sr-molar_density: 0.026291026919270048
# SrTiO3-film-2-Sr-roughness: 2.732435723027004
# SrTiO3-film-2-Ti-molar_density: 0.02637021094283215
# SrTiO3-film-2-Ti-roughness: 3.9279130189804645
# SrTiO3-film-2-O-molar_density: 0.04845953052127307
# SrTiO3-film-2-O-roughness: 2.8377697564276656
# SrTiO3-film-3-Sr-molar_density: 0.028362691697693034
# SrTiO3-film-3-Sr-roughness: 3.151544464201196
# SrTiO3-film-3-Ti-molar_density: 0.022340611439236702
# SrTiO3-film-3-Ti-roughness: 3.494144039437812
# SrTiO3-film-3-O-molar_density: 0.001114768574900754
# SrTiO3-film-3-O-roughness: 1.7955672217116125
# 27
# Data ready
# differential_evolution step 1: f(x)= 193.25010343352585
# differential_evolution step 2: f(x)= 193.25010343352585
# differential_evolution step 3: f(x)= 193.25010343352585
# differential_evolution step 4: f(x)= 193.25010343352585
# differential_evolution step 5: f(x)= 178.6375629396209
# differential_evolution step 6: f(x)= 178.34572141728347
# differential_evolution step 7: f(x)= 170.3833205861108
# differential_evolution step 8: f(x)= 170.3833205861108
# differential_evolution step 9: f(x)= 170.3833205861108
# differential_evolution step 10: f(x)= 170.3833205861108
# differential_evolution step 11: f(x)= 170.3833205861108
# differential_evolution step 12: f(x)= 170.3833205861108
# differential_evolution step 13: f(x)= 169.8581466879403
# differential_evolution step 14: f(x)= 169.8581466879403
# differential_evolution step 15: f(x)= 169.8581466879403
# differential_evolution step 16: f(x)= 169.8581466879403
# differential_evolution step 17: f(x)= 169.8581466879403
# differential_evolution step 18: f(x)= 169.8581466879403
# differential_evolution step 19: f(x)= 166.90697097681803
# differential_evolution step 20: f(x)= 166.90697097681803
# differential_evolution step 21: f(x)= 166.90697097681803
# differential_evolution step 22: f(x)= 166.90697097681803
# differential_evolution step 23: f(x)= 166.61685782348914
# differential_evolution step 24: f(x)= 166.61685782348914
# differential_evolution step 25: f(x)= 166.61685782348914
# differential_evolution step 26: f(x)= 166.61685782348914
# differential_evolution step 27: f(x)= 166.61685782348914
# differential_evolution step 28: f(x)= 165.15785357134922
# differential_evolution step 29: f(x)= 164.96027190718218
# differential_evolution step 30: f(x)= 164.96027190718218
# differential_evolution step 31: f(x)= 164.96027190718218
# differential_evolution step 32: f(x)= 164.67009412404937
# differential_evolution step 33: f(x)= 164.67009412404937
# differential_evolution step 34: f(x)= 164.67009412404937
# differential_evolution step 35: f(x)= 164.67009412404937
# differential_evolution step 36: f(x)= 164.13766430479058
# differential_evolution step 37: f(x)= 164.13766430479058
# differential_evolution step 38: f(x)= 164.13766430479058
# differential_evolution step 39: f(x)= 164.13766430479058
# differential_evolution step 40: f(x)= 163.97353140769573
# differential_evolution step 41: f(x)= 163.97353140769573
# differential_evolution step 42: f(x)= 163.58857696404544
# differential_evolution step 43: f(x)= 163.58857696404544
# differential_evolution step 44: f(x)= 163.58857696404544
# differential_evolution step 45: f(x)= 163.58857696404544
# differential_evolution step 46: f(x)= 163.58857696404544
# differential_evolution step 47: f(x)= 163.58857696404544
# differential_evolution step 48: f(x)= 163.58857696404544
# differential_evolution step 49: f(x)= 163.58857696404544
# differential_evolution step 50: f(x)= 163.4134259604336
# (array([3.70038659, 4.22037827, 2.11044129, 0.05406522, 1.84249038,
#        0.02655115, 2.71051575, 0.0472612 , 2.26208009, 0.00853518,
#        1.91590874, 0.05258713, 0.9309498 , 0.01254602, 2.55086228,
#        0.04413237, 3.29079837, 0.0065083 , 1.4431065 , 0.03663596,
#        1.3215764 , 0.00799603, 3.12802657, 0.05272442, 4.5117535 ,
#        0.03900088, 1.91927261]), 163.4134259604336)
# Final parameters:
# Current params: [3.0915587697000855, 4.4176955354089955, 3.664737535263638, 0.04524150759057016, 1.6882624042775172, 0.026619635062687066, 2.3433574449931065, 0.05156034926172571, 1.3604806051229028, 0.005862972252673203, 3.105470846871598, 0.0516546360000272, 0.24679084084755853, 0.007234743302694746, 3.8467630941060476, 0.04872409887283866, 1.9887360589852485, 0.006118331467023189, 1.0543958036586065, 0.04161530407574513, 1.2904088771889943, 0.011048113557128966, 0.9707875495292533, 0.04569634595929902, 4.298436078162716, 0.026340879019729854, 1.6917234068476794]
# SrTiO3-crystal-Sr-roughness: 3.0915587697000855
# SrTiO3-crystal-Ti-roughness: 4.4176955354089955
# SrTiO3-crystal-O-roughness: 3.664737535263638
# SrTiO3-film-0-Sr-molar_density: 0.04524150759057016
# SrTiO3-film-0-Sr-roughness: 1.6882624042775172
# SrTiO3-film-0-Ti-molar_density: 0.026619635062687066
# SrTiO3-film-0-Ti-roughness: 2.3433574449931065
# SrTiO3-film-0-O-molar_density: 0.05156034926172571
# SrTiO3-film-0-O-roughness: 1.3604806051229028
# SrTiO3-film-1-Sr-molar_density: 0.005862972252673203
# SrTiO3-film-1-Sr-roughness: 3.105470846871598
# SrTiO3-film-1-Ti-molar_density: 0.0516546360000272
# SrTiO3-film-1-Ti-roughness: 0.24679084084755853
# SrTiO3-film-1-O-molar_density: 0.007234743302694746
# SrTiO3-film-1-O-roughness: 3.8467630941060476
# SrTiO3-film-2-Sr-molar_density: 0.04872409887283866
# SrTiO3-film-2-Sr-roughness: 1.9887360589852485
# SrTiO3-film-2-Ti-molar_density: 0.006118331467023189
# SrTiO3-film-2-Ti-roughness: 1.0543958036586065
# SrTiO3-film-2-O-molar_density: 0.04161530407574513
# SrTiO3-film-2-O-roughness: 1.2904088771889943
# SrTiO3-film-3-Sr-molar_density: 0.011048113557128966
# SrTiO3-film-3-Sr-roughness: 0.9707875495292533
# SrTiO3-film-3-Ti-molar_density: 0.04569634595929902
# SrTiO3-film-3-Ti-roughness: 4.298436078162716
# SrTiO3-film-3-O-molar_density: 0.026340879019729854
# SrTiO3-film-3-O-roughness: 1.6917234068476794

# %%
crystal.thickness.set(10)
struc.update_layers()
plot_density_profile_atoms_layers(struc.atoms_layers)
for rscan in experimental_rscans:
    rsim = backend.compute_reflectivity(structure=struc, qz=rscan.qz, energy=rscan.energy_eV)
    r = rsim.R_s if rscan.pol == "s" else rsim.R_p

    plot_reflectivity(rscan.qz, np.log(rscan.R), np.log(r), rscan.energy_eV, f"Energy scan {rscan.name}")

# %%
def params_for_films(film):
    for detail in film.compound_details:
        detail.roughness.independent = False
        detail.roughness.fit = False
        detail.roughness.upper = 5.0
        detail.roughness.lower = 0.0

        detail.molar_density.independent = False
        detail.molar_density.fit = False
        detail.molar_density.upper = 0.09
        detail.molar_density.lower = 0

        detail.thickness.independent = True
        detail.thickness.fit = True
        detail.thickness.set(6)
        detail.thickness.upper = 7.0
        detail.thickness.lower = 1.0

        detail.prev_roughness.independent = False
        detail.prev_roughness.fit = False
        # detail.prev_roughness.upper = 5.0
        # detail.prev_roughness.lower = 0.0


for film in films:
    params_for_films(film)

print_parameters(parameters_container)
# Out:
# Current params: [2.2153869876788987, 2.4675075180906223, 3.033646435732006, 6.0, 6.0, 6.0, 6.0, 6.0, 6.0, 6.0, 6.0, 6.0, 6.0, 6.0, 6.0]
# SrTiO3-crystal-Sr-roughness: 2.2153869876788987
# SrTiO3-crystal-Ti-roughness: 2.4675075180906223
# SrTiO3-crystal-O-roughness: 3.033646435732006
# SrTiO3-film-0-Sr-thickness: 6
# SrTiO3-film-0-Ti-thickness: 6
# SrTiO3-film-0-O-thickness: 6
# SrTiO3-film-1-Sr-thickness: 6
# SrTiO3-film-1-Ti-thickness: 6
# SrTiO3-film-1-O-thickness: 6
# SrTiO3-film-2-Sr-thickness: 6
# SrTiO3-film-2-Ti-thickness: 6
# SrTiO3-film-2-O-thickness: 6
# SrTiO3-film-3-Sr-thickness: 6
# SrTiO3-film-3-Ti-thickness: 6
# SrTiO3-film-3-O-thickness: 6
